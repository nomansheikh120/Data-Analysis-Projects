# %% [markdown]
# # Churn analytics
# * It is the process of measuring the rate at which customers quit the product, site, or service

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# ### Task
# * Find out the best churned customers to retain them by distributing 1000 dollars coupen in total
# * Cutoff Date = last two months

# %%
dataset = pd.read_csv('rfm.txt', parse_dates=['trans_date'])
dataset.head()
# Out:
#   customer_id trans_date  tran_amount
# 0      FM5295 2017-11-11           35
# 1      FM4768 2019-12-15           39
# 2      FM2122 2017-11-26           52
# 3      FM1217 2016-08-16           99
# 4      FM1850 2018-08-20           78

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125000 entries, 0 to 124999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  125000 non-null  object
#  1   trans_date   125000 non-null  datetime64[ns]
#  2   tran_amount  125000 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.9+ MB

# %%
dataset['trans_date'].agg(['min', 'max'])
# Out:
# min   2016-02-16
# max   2019-12-16
# Name: trans_date, dtype: datetime64[ns]

# %%
cutoff_date = dt.datetime(2019, 10, 16)
print(cutoff_date)
# Out:
# 2019-10-16 00:00:00

# %% [markdown]
# ### Grouping data by customers

# %%
customer_id_groupby = dataset.groupby(['customer_id'])
customer_id_groupby.get_group('FM5295').head()
# Out:
#      customer_id trans_date  tran_amount
# 0         FM5295 2017-11-11           35
# 3556      FM5295 2019-08-25           54
# 4218      FM5295 2018-02-22           37
# 4710      FM5295 2017-09-24           36
# 5986      FM5295 2017-12-22           98

# %% [markdown]
# ### Identifying last arrival and max transaction amount

# %%
last_transection = customer_id_groupby.max()
last_transection.head()
# Out:
#             trans_date  tran_amount
# customer_id
# FM1112      2019-10-14          105
# FM1113      2019-11-09           98
# FM1114      2019-11-12          105
# FM1115      2019-12-05          104
# FM1116      2019-05-25          105

# %% [markdown]
# ### Identifying churned customers by cutoff date

# %%
churned_customers = customer_id_groupby.max()

# %%
def churned(date):
    if date <= cutoff_date:
        return 1
    else:
        return 0

# %%
churned_customers['churned'] = churned_customers.trans_date.map(churned)
churned_customers.head()
# Out:
#             trans_date  tran_amount  churned
# customer_id
# FM1112      2019-10-14          105        1
# FM1113      2019-11-09           98        0
# FM1114      2019-11-12          105        0
# FM1115      2019-12-05          104        0
# FM1116      2019-05-25          105        1

# %% [markdown]
# ### Identifying total number of transactions by each customer

# %%
churned_customers['no_of_tran'] = customer_id_groupby.size()
churned_customers['tran_total'] = customer_id_groupby['tran_amount'].sum()
churned_customers.head()
# Out:
#             trans_date  tran_amount  churned  no_of_tran  tran_total
# customer_id
# FM1112      2019-10-14          105        1          15        1012
# FM1113      2019-11-09           98        0          20        1490
# FM1114      2019-11-12          105        0          19        1432
# FM1115      2019-12-05          104        0          22        1659
# FM1116      2019-05-25          105        1          13         857

# %% [markdown]
# ### Rescaling number of transactions and transaction total

# %%
x = churned_customers.no_of_tran
churned_customers["scaled_tran"] = (x- x.min())/(x.max() - x.min())
y = churned_customers.tran_total
churned_customers["scaled_amount"] = (y- y.min())/(y.max() - y.min())
churned_customers.head()
# Out:
#             trans_date  tran_amount  churned  no_of_tran  tran_total  \
# customer_id
# FM1112      2019-10-14          105        1          15        1012
# FM1113      2019-11-09           98        0          20        1490
# FM1114      2019-11-12          105        0          19        1432
# FM1115      2019-12-05          104        0          22        1659
# FM1116      2019-05-25          105        1          13         857
#
#              scaled_tran  scaled_amount
# customer_id
# FM1112          0.314286       0.309986
# FM1113          0.457143       0.481681
# FM1114          0.428571       0.460848
# FM1115          0.514286       0.542385
# FM1116          0.257143       0.254310

# %% [markdown]
# ### Calculating Churn rate

# %%
churned_customers['score'] = round(((0.5*churned_customers['scaled_tran']) + (0.5*churned_customers['scaled_amount'])) * 100, 2)
churned_customers = churned_customers[churned_customers['churned'] == 1].sort_values(by='score', ascending=False)

# %% [markdown]
# ### Identifying 30 percent of trasaction total for top customers and diving 1000 into them

# %%
churned_customers['tran_total_30%'] = round(churned_customers['tran_amount']*.30,0).astype('int')
churned_customers['tran_total_30%'].head(32).sum()
# Out:
# 1006

# %% [markdown]
# ### Best churned customers to retain

# %%
best_churned_customers = churned_customers.head(32)
best_churned_customers
# Out:
#             trans_date  tran_amount  churned  no_of_tran  tran_total  \
# customer_id
# FM4320      2019-09-26          105        1          38        2647
# FM3799      2019-07-16          105        1          36        2513
# FM3805      2019-09-11          104        1          35        2453
# FM5752      2019-09-28          102        1          33        2612
# FM4074      2019-09-05          105        1          34        2462
# FM1215      2019-08-03          102        1          35        2362
# FM2620      2019-07-25          104        1          35        2360
# FM1580      2019-06-07          102        1          33        2329
# FM2951      2019-05-28          103        1          32        2382
# FM3163      2019-10-12          105        1          31        2413
# FM5868      2019-03-30          105        1          31        2260
# FM1695      2019-09-13          105        1          32        2174
# FM1865      2019-09-10          102        1          31        2245
# FM1757      2019-09-26          105        1          31        2238
# FM3362      2019-08-13          104        1          30        2303
# FM4329      2019-10-16          104        1          30        2301
# FM3356      2019-10-10          103        1          31        2221
# FM1978      2019-09-30          103        1          31        2220
# FM1541      2019-07-26          105        1          30        2273
# FM4303      2019-09-24          105        1          31        2181
# FM3165      2019-08-21          105        1          30        2202
# FM2361      2019-09-16          104        1          30        2193
# FM3530      2019-08-25          105        1          30        2186
# FM4139      2019-07-10          104        1          31        2099
# FM2482      2019-08-29          105        1          31        2098
# FM3702      2019-10-10          105        1          30        2175
# FM5518      2019-10-05          104        1          31        2089
# FM1397      2019-07-01          104        1          30        2156
# FM3897      2019-10-11          105        1          30        2141
# FM1923      2019-09-29          104        1          30        2130
# FM4603      2019-10-11          103        1          30        2111
# FM2284      2019-09-01          104        1          29        2179
#
#              scaled_tran  scaled_amount  score  tran_total_30%
# customer_id
# FM4320          0.971429       0.897270  93.43              32
# FM3799          0.914286       0.849138  88.17              32
# FM3805          0.885714       0.827586  85.67              31
# FM5752          0.828571       0.884698  85.66              31
# FM4074          0.857143       0.830819  84.40              32
# FM1215          0.885714       0.794899  84.03              31
# FM2620          0.885714       0.794181  83.99              31
# FM1580          0.828571       0.783046  80.58              31
# FM2951          0.800000       0.802083  80.10              31
# FM3163          0.771429       0.813218  79.23              32
# FM5868          0.771429       0.758261  76.48              32
# FM1695          0.800000       0.727371  76.37              32
# FM1865          0.771429       0.752874  76.22              31
# FM1757          0.771429       0.750359  76.09              32
# FM3362          0.742857       0.773707  75.83              31
# FM4329          0.742857       0.772989  75.79              31
# FM3356          0.771429       0.744253  75.78              31
# FM1978          0.771429       0.743894  75.77              31
# FM1541          0.742857       0.762931  75.29              32
# FM4303          0.771429       0.729885  75.07              32
# FM3165          0.742857       0.737428  74.01              32
# FM2361          0.742857       0.734195  73.85              31
# FM3530          0.742857       0.731681  73.73              32
# FM4139          0.771429       0.700431  73.59              31
# FM2482          0.771429       0.700072  73.58              32
# FM3702          0.742857       0.727730  73.53              32
# FM5518          0.771429       0.696839  73.41              31
# FM1397          0.742857       0.720905  73.19              31
# FM3897          0.742857       0.715517  72.92              32
# FM1923          0.742857       0.711566  72.72              31
# FM4603          0.742857       0.704741  72.38              31
# FM2284          0.714286       0.729167  72.17              31
